# %% [markdown]
# <a href="https://colab.research.google.com/github/MaciejAI/computer_vision/blob/main/start.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Start

# %%
# Out:
# Hello
